# %%
import timm
from timm import create_model

model = timm.create_model("convnextv2_nano",pretrained=False,num_classes = 11)
total = sum(p.numel() for p in model.parameters())
print(total * 4 / 1024 /1024)
# Out:
# 运行具有“xianyu (Python 3.10.16)”的单元格需要ipykernel包。
#
# 使用所需的包 <a href='command:jupyter.createPythonEnvAndSelectController'>创建 Python 环境</a>。
#
# 或使用命令“conda install -n xianyu ipykernel --update-deps --force-reinstall”安装“ipykernel”
