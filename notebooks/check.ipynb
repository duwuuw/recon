# %%
import timm
from timm import create_model

resnet_models = timm.list_models('*dinov*')
for model in resnet_models:
    print(model)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import timm
#       2 from timm import create_model
#       4 resnet_models = timm.list_models('*dinov*')
#
# File d:\xianyu\Lib\site-packages\timm\__init__.py:2
#       1 from .version import __version__ as __version__
# ----> 2 from .layers import (
#       3     is_scriptable as is_scriptable,
#       4     is_exportable as is_exportable,
#       5     set_scriptable as set_scriptable,
#       6     set_exportable as set_exportable,
#       7 )
#       8 from .models import (
#       9     create_model as create_model,
#      10     list_models as list_models,
#    (...)     17     get_pretrained_cfg_value as get_pretrained_cfg_value,
#      18 )
#
# File d:\xianyu\Lib\site-packages\timm\layers\__init__.py:1
# ----> 1 from ._fx import (
#       2     create_feature_extractor,
# ...
